# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import requests

from datetime import datetime

# %%
# Create list for weather data

city_data = []

# Print the beginning of the logging

print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters

record_count = 1

set_count = 1

# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
   
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 602

# %%
# Loop through city Lists 

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1 
        
        record_count = 1 
    
    # Create URL for each city
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1

# Make an API request for each city 

    try:
       
        # Parse the JSON data
        
        city_weather = requests.get(city_url).json()

        # Compile needed data
        
        city_city = city.title()
        
        city_country = city_weather['sys']['country']
        
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        city_lat = city_weather['coord']['lat']
        
        city_lng = city_weather['coord']['lon']
        
        city_max_temp = city_weather['main']['temp_max']
        
        city_hum = city_weather['main']['humidity']
        
        city_cloud = city_weather['clouds']['all']
        
        city_wind = city_weather['wind']['speed']

        # Fill City Data list 
        
        city_data.append({"City": city_city,
                          
                         "Country": city_country,
                          
                         "Date": city_date,
                          
                         "Lat": city_lat,
                          
                         "Lng": city_lng,
                          
                         "Max Temp": city_max_temp,
                          
                         "Humidity": city_hum,
                          
                         "Cloudiness": city_cloud,
                          
                         "Wind Speed": city_wind,
                          
                         })
    #If an error occurs
    
    except: 
        
        print("City not found. Skipping")
        
        pass

    # Complete Data Retrieval    
    
print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | trapani
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | bolungarvik
# City not found. Skipping
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | mangai
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | yulara
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | fort walton beach
# Processing Record 17 of Set 1 | roald
# Processing Record 18 of Set 1 | avera
# Processing Record 19 of Set 1 | coihaique
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | waingapu
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | sibolga
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | meulaboh
# Processing Record 27 of Set 1 | hambantota
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | carpentras
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | lufilufi
# Processing Record 33 of Set 1 | tonneins
# Processing Record 34 of Set 1 | taoudenni
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 36 of Set 1 | muskogee
# Processing Record 37 of Set 1 | dubbo
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | labuhan
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | bokspits
# City not found. Skipping
# Processing Record 44 of Set 1 | mosquera
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | tricase
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | dinsor
# City not found. Skipping
# Processing Record 1 of Set 2 | shache
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 3 of Set 2 | yar-sale
# Processing Record 4 of Set 2 | santa vitoria do palmar
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | peruibe
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | paita
# Processing Record 12 of Set 2 | romitan
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | novi becej
# Processing Record 15 of Set 2 | dentsville
# Processing Record 16 of Set 2 | ostrovnoy
# Processing Record 17 of Set 2 | canaries
# Processing Record 18 of Set 2 | bethlehem
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 22 of Set 2 | temaraia
# City not found. Skipping
# Processing Record 23 of Set 2 | koson
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | sao mateus
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | bubaque
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | penticton
# Processing Record 34 of Set 2 | hasaki
# Processing Record 35 of Set 2 | kavaratti
# Processing Record 36 of Set 2 | verkhniy ufaley
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | polunochnoye
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | maputo
# Processing Record 42 of Set 2 | zhangye
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | flinders
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | manzil salim
# Processing Record 47 of Set 2 | san antonio
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | maradi
# Processing Record 50 of Set 2 | bilma
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | launceston
# Processing Record 4 of Set 3 | el limon
# Processing Record 5 of Set 3 | teya
# Processing Record 6 of Set 3 | carutapera
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | bonwapitse
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | jiroft
# City not found. Skipping
# Processing Record 11 of Set 3 | ulaangom
# Processing Record 12 of Set 3 | poum
# Processing Record 13 of Set 3 | dujuma
# City not found. Skipping
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | leshukonskoye
# Processing Record 16 of Set 3 | sao miguel do araguaia
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping
# Processing Record 18 of Set 3 | constitucion
# Processing Record 19 of Set 3 | vostok
# Processing Record 20 of Set 3 | mehamn
# Processing Record 21 of Set 3 | ballina
# Processing Record 22 of Set 3 | alabushevo
# Processing Record 23 of Set 3 | korla
# Processing Record 24 of Set 3 | luwuk
# Processing Record 25 of Set 3 | yarmouth
# Processing Record 26 of Set 3 | nalut
# Processing Record 27 of Set 3 | sug-aksy
# City not found. Skipping
# Processing Record 28 of Set 3 | lasa
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | saint-augustin
# Processing Record 31 of Set 3 | palu
# Processing Record 32 of Set 3 | fayaoue
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | ontario
# Processing Record 35 of Set 3 | porgera
# Processing Record 36 of Set 3 | yumen
# Processing Record 37 of Set 3 | verkhnyaya inta
# Processing Record 38 of Set 3 | okhotsk
# Processing Record 39 of Set 3 | cabedelo
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | tucumcari
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | anju
# Processing Record 44 of Set 3 | praya
# Processing Record 45 of Set 3 | dalvik
# Processing Record 46 of Set 3 | houston
# Processing Record 47 of Set 3 | ust-tsilma
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | sao filipe
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping
# Processing Record 5 of Set 4 | port moresby
# Processing Record 6 of Set 4 | muravlenko
# Processing Record 7 of Set 4 | camargo
# Processing Record 8 of Set 4 | bolshoy lug
# Processing Record 9 of Set 4 | soyo
# Processing Record 10 of Set 4 | terra santa
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | kuche
# City not found. Skipping
# Processing Record 13 of Set 4 | anchorage
# Processing Record 14 of Set 4 | maloy
# Processing Record 15 of Set 4 | tete
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | kismayo
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | valdivia
# Processing Record 20 of Set 4 | turayf
# Processing Record 21 of Set 4 | monrovia
# Processing Record 22 of Set 4 | manzil jamil
# City not found. Skipping
# Processing Record 23 of Set 4 | ambon
# Processing Record 24 of Set 4 | lata
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | tyukhtet
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping
# Processing Record 28 of Set 4 | bonao
# Processing Record 29 of Set 4 | beaverlodge
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | maceio
# Processing Record 34 of Set 4 | saskylakh
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | kyshtovka
# Processing Record 38 of Set 4 | rajgarh
# Processing Record 39 of Set 4 | eydhafushi
# Processing Record 40 of Set 4 | cody
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping
# Processing Record 42 of Set 4 | kapuskasing
# Processing Record 43 of Set 4 | oktyabrskoye
# Processing Record 44 of Set 4 | namibe
# Processing Record 45 of Set 4 | seoul
# Processing Record 46 of Set 4 | souillac
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | wajir
# Processing Record 49 of Set 4 | angoche
# Processing Record 50 of Set 4 | nabire
# Processing Record 1 of Set 5 | urucara
# Processing Record 2 of Set 5 | eyl
# Processing Record 3 of Set 5 | berlevag
# Processing Record 4 of Set 5 | salym
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | bredasdorp
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | srandakan
# Processing Record 9 of Set 5 | veraval
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | zhangjiakou
# Processing Record 12 of Set 5 | koumac
# Processing Record 13 of Set 5 | hay river
# Processing Record 14 of Set 5 | lorengau
# Processing Record 15 of Set 5 | novovelichkovskaya
# Processing Record 16 of Set 5 | satitoa
# City not found. Skipping
# Processing Record 17 of Set 5 | ketchikan
# Processing Record 18 of Set 5 | asau
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping
# Processing Record 20 of Set 5 | salinopolis
# Processing Record 21 of Set 5 | cabatuan
# Processing Record 22 of Set 5 | raudeberg
# Processing Record 23 of Set 5 | kralendijk
# Processing Record 24 of Set 5 | mackay
# Processing Record 25 of Set 5 | taber
# Processing Record 26 of Set 5 | arraial do cabo
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | verkhnevilyuysk
# Processing Record 29 of Set 5 | bend
# Processing Record 30 of Set 5 | okato
# Processing Record 31 of Set 5 | kayankulam
# Processing Record 32 of Set 5 | vieques
# Processing Record 33 of Set 5 | bur gabo
# City not found. Skipping
# Processing Record 34 of Set 5 | ladario
# Processing Record 35 of Set 5 | inuvik
# Processing Record 36 of Set 5 | paucartambo
# City not found. Skipping
# Processing Record 37 of Set 5 | shingu
# Processing Record 38 of Set 5 | tazmalt
# Processing Record 39 of Set 5 | sao sebastiao
# Processing Record 40 of Set 5 | kloulklubed
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | nemuro
# Processing Record 43 of Set 5 | mlowo
# Processing Record 44 of Set 5 | naze
# Processing Record 45 of Set 5 | kargasok
# Processing Record 46 of Set 5 | shebekino
# Processing Record 47 of Set 5 | yinchuan
# Processing Record 48 of Set 5 | brewster
# Processing Record 49 of Set 5 | odweyne
# Processing Record 50 of Set 5 | campbellton
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | ahuimanu
# Processing Record 4 of Set 6 | san luis
# Processing Record 5 of Set 6 | syava
# Processing Record 6 of Set 6 | lac du bonnet
# Processing Record 7 of Set 6 | tuatapere
# Processing Record 8 of Set 6 | kastoria
# Processing Record 9 of Set 6 | pevek
# Processing Record 10 of Set 6 | ust-kut
# Processing Record 11 of Set 6 | sapouy
# Processing Record 12 of Set 6 | merauke
# Processing Record 13 of Set 6 | salalah
# Processing Record 14 of Set 6 | san patricio
# Processing Record 15 of Set 6 | xining
# Processing Record 16 of Set 6 | victoria
# Processing Record 17 of Set 6 | port elizabeth
# Processing Record 18 of Set 6 | coruripe
# Processing Record 19 of Set 6 | piacabucu
# Processing Record 20 of Set 6 | meiningen
# Processing Record 21 of Set 6 | samusu
# City not found. Skipping
# Processing Record 22 of Set 6 | guarapari
# Processing Record 23 of Set 6 | ferkessedougou
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | ndouci
# City not found. Skipping
# Processing Record 27 of Set 6 | nokaneng
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | duz
# City not found. Skipping
# Processing Record 30 of Set 6 | amapa
# Processing Record 31 of Set 6 | swan hill
# Processing Record 32 of Set 6 | marathon
# Processing Record 33 of Set 6 | noumea
# Processing Record 34 of Set 6 | gardner
# Processing Record 35 of Set 6 | leningradskiy
# Processing Record 36 of Set 6 | palabuhanratu
# City not found. Skipping
# Processing Record 37 of Set 6 | meadow lake
# Processing Record 38 of Set 6 | mugango
# Processing Record 39 of Set 6 | kalomo
# City not found. Skipping
# Processing Record 40 of Set 6 | galesong
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | fuling
# Processing Record 43 of Set 6 | faya
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | novelda
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | la ronge
# Processing Record 49 of Set 6 | katsuura
# Processing Record 50 of Set 6 | andenes
# Processing Record 1 of Set 7 | ngukurr
# City not found. Skipping
# Processing Record 2 of Set 7 | samana
# Processing Record 3 of Set 7 | portland
# Processing Record 4 of Set 7 | tela
# Processing Record 5 of Set 7 | talas
# Processing Record 6 of Set 7 | sangueya
# Processing Record 7 of Set 7 | rakiv lis
# Processing Record 8 of Set 7 | garowe
# Processing Record 9 of Set 7 | marcona
# City not found. Skipping
# Processing Record 10 of Set 7 | caravelas
# Processing Record 11 of Set 7 | sheffield
# Processing Record 12 of Set 7 | basco
# Processing Record 13 of Set 7 | san cristobal
# Processing Record 14 of Set 7 | krasnoselkup
# Processing Record 15 of Set 7 | key west
# Processing Record 16 of Set 7 | felidhoo
# City not found. Skipping
# Processing Record 17 of Set 7 | tarakan
# Processing Record 18 of Set 7 | nantucket
# Processing Record 19 of Set 7 | bajil
# Processing Record 20 of Set 7 | umm kaddadah
# Processing Record 21 of Set 7 | chernyanka
# Processing Record 22 of Set 7 | usakos
# Processing Record 23 of Set 7 | hamilton
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | visnes
# Processing Record 26 of Set 7 | te anau
# Processing Record 27 of Set 7 | talnakh
# Processing Record 28 of Set 7 | ingraj bazar
# Processing Record 29 of Set 7 | severo-kurilsk
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | quthing
# Processing Record 32 of Set 7 | port-gentil
# Processing Record 33 of Set 7 | tilichiki
# Processing Record 34 of Set 7 | saleaula
# City not found. Skipping
# Processing Record 35 of Set 7 | belaya gora
# Processing Record 36 of Set 7 | nizhneyansk
# City not found. Skipping
# Processing Record 37 of Set 7 | svetlaya
# Processing Record 38 of Set 7 | biograd na moru
# Processing Record 39 of Set 7 | auki
# Processing Record 40 of Set 7 | lethem
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | karachi
# Processing Record 43 of Set 7 | sur
# Processing Record 44 of Set 7 | tanjung morawa
# City not found. Skipping
# Processing Record 45 of Set 7 | salvador
# Processing Record 46 of Set 7 | tabiauea
# City not found. Skipping
# Processing Record 47 of Set 7 | gayeri
# Processing Record 48 of Set 7 | qabis
# City not found. Skipping
# Processing Record 49 of Set 7 | tagusao
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | zaysan
# Processing Record 2 of Set 8 | attawapiskat
# City not found. Skipping
# Processing Record 3 of Set 8 | necochea
# Processing Record 4 of Set 8 | sivaki
# Processing Record 5 of Set 8 | touros
# Processing Record 6 of Set 8 | marawi
# Processing Record 7 of Set 8 | skibbereen
# Processing Record 8 of Set 8 | muzhi
# Processing Record 9 of Set 8 | enshi
# Processing Record 10 of Set 8 | gat
# Processing Record 11 of Set 8 | springfield
# Processing Record 12 of Set 8 | chadan
# Processing Record 13 of Set 8 | lima
# Processing Record 14 of Set 8 | manuk mangkaw
# Processing Record 15 of Set 8 | pacific grove
# Processing Record 16 of Set 8 | bonfim
# Processing Record 17 of Set 8 | meyungs
# City not found. Skipping
# Processing Record 18 of Set 8 | baykit
# Processing Record 19 of Set 8 | whangarei
# Processing Record 20 of Set 8 | progreso
# Processing Record 21 of Set 8 | cassilandia
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | ocampo
# Processing Record 24 of Set 8 | jumla
# Processing Record 25 of Set 8 | sinkat
# City not found. Skipping
# Processing Record 26 of Set 8 | pathein
# Processing Record 27 of Set 8 | lompoc
# Processing Record 28 of Set 8 | west odessa
# Processing Record 29 of Set 8 | ribeira grande
# Processing Record 30 of Set 8 | presidencia roque saenz pena
# Processing Record 31 of Set 8 | khingansk
# Processing Record 32 of Set 8 | houma
# Processing Record 33 of Set 8 | hobyo
# Processing Record 34 of Set 8 | chicama
# Processing Record 35 of Set 8 | ilo
# Processing Record 36 of Set 8 | victor harbor
# Processing Record 37 of Set 8 | roebourne
# Processing Record 38 of Set 8 | ilek
# Processing Record 39 of Set 8 | biltine
# Processing Record 40 of Set 8 | khilok
# Processing Record 41 of Set 8 | mizdah
# Processing Record 42 of Set 8 | mosalsk
# Processing Record 43 of Set 8 | princeton
# Processing Record 44 of Set 8 | los llanos de aridane
# Processing Record 45 of Set 8 | sasolburg
# Processing Record 46 of Set 8 | raga
# Processing Record 47 of Set 8 | tonantins
# Processing Record 48 of Set 8 | kalmunai
# Processing Record 49 of Set 8 | tautira
# Processing Record 50 of Set 8 | itaituba
# Processing Record 1 of Set 9 | sinjar
# Processing Record 2 of Set 9 | malanje
# Processing Record 3 of Set 9 | richards bay
# Processing Record 4 of Set 9 | coihueco
# Processing Record 5 of Set 9 | marsh harbour
# Processing Record 6 of Set 9 | qasigiannguit
# Processing Record 7 of Set 9 | kyzyl-suu
# Processing Record 8 of Set 9 | juba
# Processing Record 9 of Set 9 | nanga eboko
# Processing Record 10 of Set 9 | burns lake
# Processing Record 11 of Set 9 | comodoro rivadavia
# Processing Record 12 of Set 9 | tadine
# Processing Record 13 of Set 9 | sitangkai
# Processing Record 14 of Set 9 | saint-georges
# Processing Record 15 of Set 9 | beringovskiy
# Processing Record 16 of Set 9 | shenkursk
# Processing Record 17 of Set 9 | senador jose porfirio
# Processing Record 18 of Set 9 | leova
# Processing Record 19 of Set 9 | magadan
# Processing Record 20 of Set 9 | el dorado
# Processing Record 21 of Set 9 | bobonong
# City not found. Skipping
# Processing Record 22 of Set 9 | rawson
# Processing Record 23 of Set 9 | chepo
# Processing Record 24 of Set 9 | dwarka
# Processing Record 25 of Set 9 | marovoay
# Processing Record 26 of Set 9 | buala
# Processing Record 27 of Set 9 | duekoue
# Processing Record 28 of Set 9 | grand river south east
# City not found. Skipping
# Processing Record 29 of Set 9 | mount isa
# Processing Record 30 of Set 9 | zapolyarnyy
# Processing Record 31 of Set 9 | totton
# Processing Record 32 of Set 9 | ambilobe
# Processing Record 33 of Set 9 | montorio al vomano
# Processing Record 34 of Set 9 | henties bay
# Processing Record 35 of Set 9 | luderitz
# Processing Record 36 of Set 9 | flin flon
# Processing Record 37 of Set 9 | yubari
# Processing Record 38 of Set 9 | abha
# Processing Record 39 of Set 9 | carballo
# Processing Record 40 of Set 9 | bulaevo
# Processing Record 41 of Set 9 | coahuayana
# Processing Record 42 of Set 9 | port hedland
# Processing Record 43 of Set 9 | olafsvik
# Processing Record 44 of Set 9 | husavik
# Processing Record 45 of Set 9 | stephenville
# Processing Record 46 of Set 9 | pringsewu
# Processing Record 47 of Set 9 | buckingham
# Processing Record 48 of Set 9 | hovd
# Processing Record 49 of Set 9 | jacareacanga
# Processing Record 50 of Set 9 | port hardy
# Processing Record 1 of Set 10 | puerto ayacucho
# Processing Record 2 of Set 10 | middelburg
# Processing Record 3 of Set 10 | baculin
# Processing Record 4 of Set 10 | mana
# Processing Record 5 of Set 10 | arlit
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping
# Processing Record 7 of Set 10 | komsomolskiy
# Processing Record 8 of Set 10 | erenhot
# Processing Record 9 of Set 10 | chimbote
# Processing Record 10 of Set 10 | saint-pierre
# Processing Record 11 of Set 10 | balotra
# Processing Record 12 of Set 10 | taseyevo
# Processing Record 13 of Set 10 | baruun-urt
# Processing Record 14 of Set 10 | sudova vyshnya
# Processing Record 15 of Set 10 | fare
# Processing Record 16 of Set 10 | clyde river
# Processing Record 17 of Set 10 | fairbanks
# Processing Record 18 of Set 10 | makat
# Processing Record 19 of Set 10 | harper
# Processing Record 20 of Set 10 | gamba
# Processing Record 21 of Set 10 | zabol
# Processing Record 22 of Set 10 | broken hill
# Processing Record 23 of Set 10 | lushunkou
# City not found. Skipping
# Processing Record 24 of Set 10 | sao jose da coroa grande
# Processing Record 25 of Set 10 | rundu
# Processing Record 26 of Set 10 | siuna
# Processing Record 27 of Set 10 | vila franca do campo
# Processing Record 28 of Set 10 | mattawa
# Processing Record 29 of Set 10 | broome
# Processing Record 30 of Set 10 | kalispell
# Processing Record 31 of Set 10 | buraydah
# Processing Record 32 of Set 10 | torbay
# Processing Record 33 of Set 10 | tartus
# Processing Record 34 of Set 10 | tiruttani
# Processing Record 35 of Set 10 | borborema
# Processing Record 36 of Set 10 | tamandare
# Processing Record 37 of Set 10 | porto belo
# Processing Record 38 of Set 10 | warren
# Processing Record 39 of Set 10 | bongandanga
# Processing Record 40 of Set 10 | raton
# Processing Record 41 of Set 10 | longlac
# City not found. Skipping
# Processing Record 42 of Set 10 | hammerfest
# Processing Record 43 of Set 10 | kutum
# Processing Record 44 of Set 10 | general pico
# Processing Record 45 of Set 10 | aklavik
# Processing Record 46 of Set 10 | port blair
# Processing Record 47 of Set 10 | shimoda
# Processing Record 48 of Set 10 | lavrentiya
# Processing Record 49 of Set 10 | anadyr
# Processing Record 50 of Set 10 | colon
# Processing Record 1 of Set 11 | santa ines
# Processing Record 2 of Set 11 | viedma
# Processing Record 3 of Set 11 | cururupu
# Processing Record 4 of Set 11 | mathathane
# Processing Record 5 of Set 11 | katima mulilo
# Processing Record 6 of Set 11 | codrington
# Processing Record 7 of Set 11 | arua
# Processing Record 8 of Set 11 | itarare
# Processing Record 9 of Set 11 | belle fourche
# Processing Record 10 of Set 11 | lakatoro
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | dudinka
# Processing Record 13 of Set 11 | nuevo progreso
# Processing Record 14 of Set 11 | tessalit
# Processing Record 15 of Set 11 | hualmay
# Processing Record 16 of Set 11 | ponnani
# Processing Record 17 of Set 11 | tabou
# Processing Record 18 of Set 11 | nacala
# Processing Record 19 of Set 11 | seymchan
# Processing Record 20 of Set 11 | leczna
# Processing Record 21 of Set 11 | sola
# Processing Record 22 of Set 11 | kamal
# Processing Record 23 of Set 11 | malakal
# Processing Record 24 of Set 11 | puerto del rosario
# Processing Record 25 of Set 11 | acajutla
# Processing Record 26 of Set 11 | eldikan
# City not found. Skipping
# Processing Record 27 of Set 11 | pemba
# Processing Record 28 of Set 11 | north platte
# Processing Record 29 of Set 11 | half moon bay
# Processing Record 30 of Set 11 | new richmond
# Processing Record 31 of Set 11 | saint-marc-des-carrieres
# Processing Record 32 of Set 11 | santa cruz del sur
# Processing Record 33 of Set 11 | alotau
# City not found. Skipping
# Processing Record 34 of Set 11 | banda aceh
# Processing Record 35 of Set 11 | laizhou
# Processing Record 36 of Set 11 | ruidoso
# Processing Record 37 of Set 11 | mitsamiouli
# Processing Record 38 of Set 11 | marrakesh
# Processing Record 39 of Set 11 | ayacucho
# Processing Record 40 of Set 11 | nogliki
# Processing Record 41 of Set 11 | beloha
# Processing Record 42 of Set 11 | straumen
# Processing Record 43 of Set 11 | byron bay
# Processing Record 44 of Set 11 | makakilo city
# Processing Record 45 of Set 11 | wajima
# Processing Record 46 of Set 11 | prince rupert
# Processing Record 47 of Set 11 | omboue
# Processing Record 48 of Set 11 | hihifo
# City not found. Skipping
# Processing Record 49 of Set 11 | bad reichenhall
# Processing Record 50 of Set 11 | jabiru
# City not found. Skipping
# Processing Record 1 of Set 12 | corinto
# Processing Record 2 of Set 12 | pangai
# Processing Record 3 of Set 12 | kiama
# Processing Record 4 of Set 12 | manavgat
# Processing Record 5 of Set 12 | malwan
# City not found. Skipping
# Processing Record 6 of Set 12 | gornopravdinsk
# Processing Record 7 of Set 12 | camacha
# Processing Record 8 of Set 12 | mamlyutka
# Processing Record 9 of Set 12 | oil city
# Processing Record 10 of Set 12 | tual
# Processing Record 11 of Set 12 | tandil
# Processing Record 12 of Set 12 | santa marta
# Processing Record 13 of Set 12 | acari
# Processing Record 14 of Set 12 | batsfjord
# Processing Record 15 of Set 12 | hurghada
# Processing Record 16 of Set 12 | ollioules
# Processing Record 17 of Set 12 | colesberg
# Processing Record 18 of Set 12 | ouesso
# Processing Record 19 of Set 12 | northam
# Processing Record 20 of Set 12 | dingle
# Processing Record 21 of Set 12 | la presa
# Processing Record 22 of Set 12 | hami
# Processing Record 23 of Set 12 | la ciotat
# Processing Record 24 of Set 12 | segou
# Processing Record 25 of Set 12 | ondangwa
# Processing Record 26 of Set 12 | oranjemund
# Processing Record 27 of Set 12 | morros
# Processing Record 28 of Set 12 | darlowo
# Processing Record 29 of Set 12 | cabra
# Processing Record 30 of Set 12 | iquique
# Processing Record 31 of Set 12 | arnprior
# Processing Record 32 of Set 12 | thinadhoo
# Processing Record 33 of Set 12 | ishigaki
# Processing Record 34 of Set 12 | taltal
# Processing Record 35 of Set 12 | acapulco
# Processing Record 36 of Set 12 | horsham
# Processing Record 37 of Set 12 | musoma
# Processing Record 38 of Set 12 | shawnee
# Processing Record 39 of Set 12 | kavieng
# Processing Record 40 of Set 12 | torrijos
# Processing Record 41 of Set 12 | vanavara
# Processing Record 42 of Set 12 | otane
# Processing Record 43 of Set 12 | champerico
# Processing Record 44 of Set 12 | gurskoye
# City not found. Skipping
# Processing Record 45 of Set 12 | show low
# Processing Record 46 of Set 12 | baiyin
# Processing Record 47 of Set 12 | calama
# Processing Record 48 of Set 12 | snasa
# Processing Record 49 of Set 12 | nhulunbuy
# Processing Record 50 of Set 12 | ambulu
# Processing Record 1 of Set 13 | lydenburg
# Processing Record 2 of Set 13 | chapleau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)

# %%
# Create the output file (CSV).

output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.

import time

# Get today's date in seconds.

today = time.time()

today
# Out:
# 1651957523.750963

# %%
# Import time module

import time

# Build the scatter plot for latitude vs. max temperature.

plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))

plt.ylabel("Max Temperature (F)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig1.png")

# Show plot.

plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.

plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))

plt.ylabel("Humidity (%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig1.png")

# Show plot.

plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.

plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))

plt.ylabel("Cloudiness (%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig3.png")

# Show plot.

plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.

plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))

plt.ylabel("Wind Speed (mph)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig4.png")

# Show plot.

plt.show()

# %%
# Import linregress

from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data

# and plot a regression line and the equation with the data.

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    
    plt.scatter(x_values,y_values)
    
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
    
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    plt.title(title)
    
    plt.xlabel('Latitude')
    
    plt.ylabel(y_label)
    
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Busselton
# Country                        AU
# Date          2022-05-07 21:00:37
# Lat                        -33.65
# Lng                      115.3333
# Max Temp                    60.48
# Humidity                       63
# Cloudiness                     82
# Wind Speed                   3.29
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 548     True
# 549    False
# 550    False
# 551    False
# 552     True
# Name: Lat, Length: 553, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#                  City Country                 Date      Lat       Lng  \
# 4           Jamestown      US  2022-05-07 20:58:52  42.0970  -79.2353
# 5             Trapani      IT  2022-05-07 21:00:34  37.8333   12.6667
# 7            Thompson      CA  2022-05-07 21:00:17  55.7435  -97.8558
# 9               Kapaa      US  2022-05-07 21:00:35  22.0752 -159.3190
# 14  Fort Walton Beach      US  2022-05-07 21:00:38  30.4058  -86.6188
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 4      65.52        40          43        8.99
# 5      60.28        93          31        1.43
# 7      64.92        71          57       10.00
# 9      80.58        82          90        5.99
# 14     87.67        60           0       13.80

# %%
# Create Northern and Southern Hemisphere DataFrames.

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Max Temp"]

# Call the function.

plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \ for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Max Temp"]

# Call the function.

plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \ for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Humidity"]

# Call the function.

plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \ for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Humidity"]

# Call the function.

plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \ for % Humidity', '% Humidity',(-50,15))

# %%
# Build the scatter plots for latitude vs. cloudiness.

plt.scatter(lats,cloudiness,edgecolor="black", linewidths=1, marker="o",alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))

plt.ylabel("Cloudiness (%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig3.png")

# Show plot.

plt.show()

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Cloudiness"]

# Call the function.

plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \ for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Wind Speed"]

# Call the function.

plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \ for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Wind Speed"]

# Call the function.

plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \ for Wind Speed', 'Wind Speed',(-50,35))
