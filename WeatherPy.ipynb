# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import requests

from datetime import datetime

# %%
# Create list for weather data

city_data = []

# Print the beginning of the logging

print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters

record_count = 1

set_count = 1

# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
   
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 612

# %%
# Loop through city Lists 

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1 
        
        record_count = 1 
    
    # Create URL for each city
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1

# Make an API request for each city 

    try:
       
        # Parse the JSON data
        
        city_weather = requests.get(city_url).json()

        # Compile needed data
        
        city_city = city.title()
        
        city_country = city_weather['sys']['country']
        
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        city_lat = city_weather['coord']['lat']
        
        city_lng = city_weather['coord']['lon']
        
        city_max_temp = city_weather['main']['temp_max']
        
        city_hum = city_weather['main']['humidity']
        
        city_cloud = city_weather['clouds']['all']
        
        city_wind = city_weather['wind']['speed']

        # Fill City Data list 
        
        city_data.append({"City": city_city,
                          
                         "Country": city_country,
                          
                         "Date": city_date,
                          
                         "Lat": city_lat,
                          
                         "Lng": city_lng,
                          
                         "Max Temp": city_max_temp,
                          
                         "Humidity": city_hum,
                          
                         "Cloudiness": city_cloud,
                          
                         "Wind Speed": city_wind,
                          
                         })
    #If an error occurs
    
    except: 
        
        print("City not found. Skipping")
        
        pass

    # Complete Data Retrieval    
    
print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | pisco
# Processing Record 5 of Set 1 | san luis
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | hunza
# City not found. Skipping
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | polunochnoye
# Processing Record 11 of Set 1 | saint-louis
# Processing Record 12 of Set 1 | urusha
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | grindavik
# Processing Record 17 of Set 1 | padang
# Processing Record 18 of Set 1 | lorengau
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 21 of Set 1 | tarbes
# Processing Record 22 of Set 1 | dolbeau
# City not found. Skipping
# Processing Record 23 of Set 1 | port-gentil
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | yomitan
# City not found. Skipping
# Processing Record 26 of Set 1 | buta
# Processing Record 27 of Set 1 | roald
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | sarangani
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | port augusta
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | muros
# Processing Record 39 of Set 1 | imperia
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | yaan
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping
# Processing Record 43 of Set 1 | belmonte
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | huai yot
# Processing Record 47 of Set 1 | morondava
# Processing Record 48 of Set 1 | malakal
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping
# Processing Record 1 of Set 2 | nelson bay
# Processing Record 2 of Set 2 | matara
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | codrington
# Processing Record 6 of Set 2 | mayumba
# Processing Record 7 of Set 2 | shirokiy
# Processing Record 8 of Set 2 | jinchengjiang
# City not found. Skipping
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | kiunga
# Processing Record 11 of Set 2 | yunjinghong
# City not found. Skipping
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | satitoa
# City not found. Skipping
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | mangrol
# Processing Record 17 of Set 2 | sheltozero
# Processing Record 18 of Set 2 | zhoucheng
# Processing Record 19 of Set 2 | kharan
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | osakarovka
# Processing Record 22 of Set 2 | lasa
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | saquarema
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | graaff-reinet
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | suruc
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | beloha
# Processing Record 36 of Set 2 | oktyabrskoye
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | rocha
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping
# Processing Record 40 of Set 2 | margate
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | nahariyya
# Processing Record 43 of Set 2 | svetlogorsk
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | shingu
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | grand gaube
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | hobart
# Processing Record 3 of Set 3 | umzimvubu
# City not found. Skipping
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | hirara
# Processing Record 7 of Set 3 | catabola
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | kattivakkam
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | silver city
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | nouadhibou
# Processing Record 19 of Set 3 | viligili
# City not found. Skipping
# Processing Record 20 of Set 3 | bodoco
# City not found. Skipping
# Processing Record 21 of Set 3 | canton
# Processing Record 22 of Set 3 | carutapera
# Processing Record 23 of Set 3 | iquitos
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | sambava
# Processing Record 28 of Set 3 | maceio
# Processing Record 29 of Set 3 | quesnel
# Processing Record 30 of Set 3 | lethem
# Processing Record 31 of Set 3 | palmer
# Processing Record 32 of Set 3 | pierre
# Processing Record 33 of Set 3 | sur
# Processing Record 34 of Set 3 | avera
# Processing Record 35 of Set 3 | labuhan
# Processing Record 36 of Set 3 | semirara
# Processing Record 37 of Set 3 | santa fe
# Processing Record 38 of Set 3 | honningsvag
# Processing Record 39 of Set 3 | uvat
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | palabuhanratu
# City not found. Skipping
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 44 of Set 3 | sosnovo-ozerskoye
# Processing Record 45 of Set 3 | azovo
# Processing Record 46 of Set 3 | kukes
# Processing Record 47 of Set 3 | voh
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | zhovtneve
# Processing Record 3 of Set 4 | ternate
# Processing Record 4 of Set 4 | barabai
# Processing Record 5 of Set 4 | tabou
# Processing Record 6 of Set 4 | rockland
# Processing Record 7 of Set 4 | bonthe
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | rolim de moura
# City not found. Skipping
# Processing Record 11 of Set 4 | plettenberg bay
# Processing Record 12 of Set 4 | ouadda
# Processing Record 13 of Set 4 | limpapa
# Processing Record 14 of Set 4 | barrow
# Processing Record 15 of Set 4 | flinders
# Processing Record 16 of Set 4 | casma
# Processing Record 17 of Set 4 | bolshaya chernigovka
# City not found. Skipping
# Processing Record 18 of Set 4 | cairns
# Processing Record 19 of Set 4 | kempele
# Processing Record 20 of Set 4 | springbok
# Processing Record 21 of Set 4 | ismailia
# Processing Record 22 of Set 4 | tiksi
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 25 of Set 4 | esperance
# Processing Record 26 of Set 4 | campo maior
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | vestmannaeyjar
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | great falls
# Processing Record 31 of Set 4 | gurlan
# Processing Record 32 of Set 4 | yekaterinovka
# Processing Record 33 of Set 4 | savannah bight
# Processing Record 34 of Set 4 | kirakira
# Processing Record 35 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping
# Processing Record 36 of Set 4 | jalu
# Processing Record 37 of Set 4 | chagda
# City not found. Skipping
# Processing Record 38 of Set 4 | hobyo
# Processing Record 39 of Set 4 | sulangan
# Processing Record 40 of Set 4 | havre-saint-pierre
# Processing Record 41 of Set 4 | sechura
# Processing Record 42 of Set 4 | bluff
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | la macarena
# Processing Record 45 of Set 4 | lavrentiya
# Processing Record 46 of Set 4 | nikolskoye
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | mangaluru
# Processing Record 49 of Set 4 | severo-yeniseyskiy
# Processing Record 50 of Set 4 | krasnovishersk
# Processing Record 1 of Set 5 | gat
# Processing Record 2 of Set 5 | along
# Processing Record 3 of Set 5 | murovane
# Processing Record 4 of Set 5 | mnogovershinnyy
# Processing Record 5 of Set 5 | yellandu
# Processing Record 6 of Set 5 | kodyma
# Processing Record 7 of Set 5 | rossland
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | doha
# Processing Record 11 of Set 5 | porto belo
# Processing Record 12 of Set 5 | birao
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | taolanaro
# City not found. Skipping
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | visakhapatnam
# Processing Record 18 of Set 5 | chokurdakh
# Processing Record 19 of Set 5 | guder
# Processing Record 20 of Set 5 | cockburn town
# Processing Record 21 of Set 5 | balykshi
# Processing Record 22 of Set 5 | poum
# Processing Record 23 of Set 5 | zelenoborskiy
# Processing Record 24 of Set 5 | nakambala
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | qaqortoq
# Processing Record 27 of Set 5 | meulaboh
# Processing Record 28 of Set 5 | mogadishu
# Processing Record 29 of Set 5 | ezhou
# Processing Record 30 of Set 5 | santa rosa
# Processing Record 31 of Set 5 | ostersund
# Processing Record 32 of Set 5 | koygorodok
# Processing Record 33 of Set 5 | huangzhou
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | saumur
# Processing Record 37 of Set 5 | aden
# Processing Record 38 of Set 5 | tahoua
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | vila franca do campo
# Processing Record 41 of Set 5 | saint-pierre
# Processing Record 42 of Set 5 | surgut
# Processing Record 43 of Set 5 | udachnyy
# Processing Record 44 of Set 5 | thinadhoo
# Processing Record 45 of Set 5 | broken hill
# Processing Record 46 of Set 5 | victor harbor
# Processing Record 47 of Set 5 | north myrtle beach
# Processing Record 48 of Set 5 | byron bay
# Processing Record 49 of Set 5 | naica
# Processing Record 50 of Set 5 | melito di porto salvo
# Processing Record 1 of Set 6 | baykit
# Processing Record 2 of Set 6 | altay
# Processing Record 3 of Set 6 | mehamn
# Processing Record 4 of Set 6 | clyde river
# Processing Record 5 of Set 6 | vostok
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | yeletskiy
# City not found. Skipping
# Processing Record 8 of Set 6 | gewane
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | hofn
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | yarmouth
# Processing Record 13 of Set 6 | katsuura
# Processing Record 14 of Set 6 | tahe
# Processing Record 15 of Set 6 | ormara
# Processing Record 16 of Set 6 | karkaralinsk
# City not found. Skipping
# Processing Record 17 of Set 6 | kysyl-syr
# Processing Record 18 of Set 6 | hilo
# Processing Record 19 of Set 6 | ligayan
# Processing Record 20 of Set 6 | leh
# Processing Record 21 of Set 6 | odweyne
# Processing Record 22 of Set 6 | visby
# Processing Record 23 of Set 6 | monrovia
# Processing Record 24 of Set 6 | ekhabi
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | umbuzeiro
# Processing Record 27 of Set 6 | naryan-mar
# Processing Record 28 of Set 6 | mabaruma
# Processing Record 29 of Set 6 | valkla
# Processing Record 30 of Set 6 | ipixuna
# Processing Record 31 of Set 6 | craig
# Processing Record 32 of Set 6 | aberystwyth
# Processing Record 33 of Set 6 | karratha
# Processing Record 34 of Set 6 | black river
# Processing Record 35 of Set 6 | cap malheureux
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | richards bay
# Processing Record 38 of Set 6 | dikson
# Processing Record 39 of Set 6 | faya
# Processing Record 40 of Set 6 | grand-santi
# Processing Record 41 of Set 6 | tidore
# City not found. Skipping
# Processing Record 42 of Set 6 | melo
# Processing Record 43 of Set 6 | antsohihy
# Processing Record 44 of Set 6 | tessalit
# Processing Record 45 of Set 6 | la union
# Processing Record 46 of Set 6 | lata
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | polyarnyy
# Processing Record 50 of Set 6 | dajabon
# Processing Record 1 of Set 7 | wittstock
# Processing Record 2 of Set 7 | winder
# Processing Record 3 of Set 7 | kasama
# Processing Record 4 of Set 7 | krasnoselkup
# Processing Record 5 of Set 7 | tambopata
# Processing Record 6 of Set 7 | sola
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | baft
# Processing Record 9 of Set 7 | kroya
# Processing Record 10 of Set 7 | surt
# Processing Record 11 of Set 7 | kholtoson
# Processing Record 12 of Set 7 | buala
# Processing Record 13 of Set 7 | dhidhdhoo
# Processing Record 14 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 7 | port keats
# Processing Record 16 of Set 7 | macas
# Processing Record 17 of Set 7 | okha
# Processing Record 18 of Set 7 | gotsu
# Processing Record 19 of Set 7 | tevaitoa
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | iraray
# Processing Record 22 of Set 7 | santa cruz
# Processing Record 23 of Set 7 | severnyy
# Processing Record 24 of Set 7 | bumba
# Processing Record 25 of Set 7 | ahome
# Processing Record 26 of Set 7 | hay river
# Processing Record 27 of Set 7 | itarema
# Processing Record 28 of Set 7 | tabiauea
# City not found. Skipping
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | tilichiki
# Processing Record 31 of Set 7 | sao jose da coroa grande
# Processing Record 32 of Set 7 | oriximina
# Processing Record 33 of Set 7 | cascais
# Processing Record 34 of Set 7 | ilulissat
# Processing Record 35 of Set 7 | zhuhai
# Processing Record 36 of Set 7 | cheney
# Processing Record 37 of Set 7 | oranjestad
# Processing Record 38 of Set 7 | college
# Processing Record 39 of Set 7 | provideniya
# Processing Record 40 of Set 7 | tignere
# Processing Record 41 of Set 7 | alice springs
# Processing Record 42 of Set 7 | zhaotong
# Processing Record 43 of Set 7 | zhangjiakou
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | tarko-sale
# Processing Record 46 of Set 7 | chicama
# Processing Record 47 of Set 7 | sibolga
# Processing Record 48 of Set 7 | oksfjord
# Processing Record 49 of Set 7 | nemuro
# Processing Record 50 of Set 7 | ratnagiri
# Processing Record 1 of Set 8 | luderitz
# Processing Record 2 of Set 8 | castanos
# Processing Record 3 of Set 8 | phrai bung
# City not found. Skipping
# Processing Record 4 of Set 8 | little current
# Processing Record 5 of Set 8 | salalah
# Processing Record 6 of Set 8 | bima
# Processing Record 7 of Set 8 | baherden
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping
# Processing Record 9 of Set 8 | malanje
# Processing Record 10 of Set 8 | xai-xai
# Processing Record 11 of Set 8 | te anau
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | benguela
# Processing Record 14 of Set 8 | talara
# Processing Record 15 of Set 8 | watertown
# Processing Record 16 of Set 8 | weiser
# Processing Record 17 of Set 8 | the valley
# Processing Record 18 of Set 8 | ketchikan
# Processing Record 19 of Set 8 | ondjiva
# Processing Record 20 of Set 8 | bontang
# Processing Record 21 of Set 8 | gwanda
# Processing Record 22 of Set 8 | gaspe
# Processing Record 23 of Set 8 | whitehorse
# Processing Record 24 of Set 8 | samalaeulu
# City not found. Skipping
# Processing Record 25 of Set 8 | hisor
# Processing Record 26 of Set 8 | zory
# Processing Record 27 of Set 8 | prince rupert
# Processing Record 28 of Set 8 | aflu
# City not found. Skipping
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | kamenskoye
# City not found. Skipping
# Processing Record 31 of Set 8 | aripuana
# Processing Record 32 of Set 8 | sobolevo
# Processing Record 33 of Set 8 | ulaanbaatar
# Processing Record 34 of Set 8 | taoudenni
# Processing Record 35 of Set 8 | aitape
# Processing Record 36 of Set 8 | santarem
# Processing Record 37 of Set 8 | maniitsoq
# Processing Record 38 of Set 8 | torquay
# Processing Record 39 of Set 8 | biysk
# Processing Record 40 of Set 8 | christchurch
# Processing Record 41 of Set 8 | menongue
# Processing Record 42 of Set 8 | dukat
# Processing Record 43 of Set 8 | oga
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping
# Processing Record 45 of Set 8 | nevelsk
# Processing Record 46 of Set 8 | cukai
# Processing Record 47 of Set 8 | fairview
# Processing Record 48 of Set 8 | portland
# Processing Record 49 of Set 8 | batsfjord
# Processing Record 50 of Set 8 | bethel
# Processing Record 1 of Set 9 | isangel
# Processing Record 2 of Set 9 | pangnirtung
# Processing Record 3 of Set 9 | ossora
# Processing Record 4 of Set 9 | japura
# Processing Record 5 of Set 9 | inhambane
# Processing Record 6 of Set 9 | shirvan
# Processing Record 7 of Set 9 | axim
# Processing Record 8 of Set 9 | bay saint louis
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | tautira
# Processing Record 11 of Set 9 | san ramon
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | pasni
# Processing Record 14 of Set 9 | hami
# Processing Record 15 of Set 9 | balsas
# Processing Record 16 of Set 9 | plainview
# Processing Record 17 of Set 9 | devils lake
# Processing Record 18 of Set 9 | elko
# Processing Record 19 of Set 9 | alofi
# Processing Record 20 of Set 9 | nautla
# Processing Record 21 of Set 9 | loiza
# Processing Record 22 of Set 9 | maun
# Processing Record 23 of Set 9 | fukue
# Processing Record 24 of Set 9 | najran
# Processing Record 25 of Set 9 | praya
# Processing Record 26 of Set 9 | abu samrah
# Processing Record 27 of Set 9 | solnechnyy
# Processing Record 28 of Set 9 | husavik
# Processing Record 29 of Set 9 | dzialdowo
# Processing Record 30 of Set 9 | kimbe
# Processing Record 31 of Set 9 | sikar
# Processing Record 32 of Set 9 | san pedro de macoris
# Processing Record 33 of Set 9 | priiskovyy
# Processing Record 34 of Set 9 | merrill
# Processing Record 35 of Set 9 | price
# Processing Record 36 of Set 9 | kangasala
# Processing Record 37 of Set 9 | quatre cocos
# Processing Record 38 of Set 9 | teberda
# Processing Record 39 of Set 9 | raga
# Processing Record 40 of Set 9 | glendive
# Processing Record 41 of Set 9 | campbell river
# Processing Record 42 of Set 9 | turayf
# Processing Record 43 of Set 9 | falealupo
# City not found. Skipping
# Processing Record 44 of Set 9 | cayenne
# Processing Record 45 of Set 9 | sterling
# Processing Record 46 of Set 9 | bitung
# Processing Record 47 of Set 9 | port said
# Processing Record 48 of Set 9 | okitipupa
# Processing Record 49 of Set 9 | zhob
# Processing Record 50 of Set 9 | ruatoria
# City not found. Skipping
# Processing Record 1 of Set 10 | lufilufi
# Processing Record 2 of Set 10 | sainte-rose
# Processing Record 3 of Set 10 | norman wells
# Processing Record 4 of Set 10 | ciudad bolivar
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | ambilobe
# Processing Record 7 of Set 10 | maldonado
# Processing Record 8 of Set 10 | sao jose do belmonte
# Processing Record 9 of Set 10 | jacareacanga
# Processing Record 10 of Set 10 | port hardy
# Processing Record 11 of Set 10 | souillac
# Processing Record 12 of Set 10 | kasongo-lunda
# Processing Record 13 of Set 10 | sarany
# Processing Record 14 of Set 10 | kieta
# Processing Record 15 of Set 10 | yerbogachen
# Processing Record 16 of Set 10 | weatherford
# Processing Record 17 of Set 10 | mzimba
# Processing Record 18 of Set 10 | beringovskiy
# Processing Record 19 of Set 10 | rawlins
# Processing Record 20 of Set 10 | soller
# Processing Record 21 of Set 10 | great malvern
# Processing Record 22 of Set 10 | bourail
# Processing Record 23 of Set 10 | comodoro rivadavia
# Processing Record 24 of Set 10 | aiquile
# Processing Record 25 of Set 10 | formosa do rio preto
# Processing Record 26 of Set 10 | gisborne
# Processing Record 27 of Set 10 | erenhot
# Processing Record 28 of Set 10 | litovko
# Processing Record 29 of Set 10 | porto novo
# Processing Record 30 of Set 10 | sijunjung
# Processing Record 31 of Set 10 | jaen
# Processing Record 32 of Set 10 | khowst
# Processing Record 33 of Set 10 | aksu
# Processing Record 34 of Set 10 | vardo
# Processing Record 35 of Set 10 | stornoway
# Processing Record 36 of Set 10 | kirkenes
# Processing Record 37 of Set 10 | camocim
# Processing Record 38 of Set 10 | acapulco
# Processing Record 39 of Set 10 | sawtell
# Processing Record 40 of Set 10 | sabang
# Processing Record 41 of Set 10 | gizo
# Processing Record 42 of Set 10 | barentsburg
# City not found. Skipping
# Processing Record 43 of Set 10 | xuddur
# Processing Record 44 of Set 10 | vaitupu
# City not found. Skipping
# Processing Record 45 of Set 10 | severodvinsk
# Processing Record 46 of Set 10 | bilibino
# Processing Record 47 of Set 10 | yagodnoye
# Processing Record 48 of Set 10 | auki
# Processing Record 49 of Set 10 | gazanjyk
# Processing Record 50 of Set 10 | san juan
# Processing Record 1 of Set 11 | san cristobal
# Processing Record 2 of Set 11 | marsh harbour
# Processing Record 3 of Set 11 | banyo
# Processing Record 4 of Set 11 | trinidad
# Processing Record 5 of Set 11 | poya
# Processing Record 6 of Set 11 | colonial heights
# Processing Record 7 of Set 11 | jinxiang
# Processing Record 8 of Set 11 | ahuimanu
# Processing Record 9 of Set 11 | redmond
# Processing Record 10 of Set 11 | srednekolymsk
# Processing Record 11 of Set 11 | neuquen
# Processing Record 12 of Set 11 | iqaluit
# Processing Record 13 of Set 11 | esna
# Processing Record 14 of Set 11 | nancha
# Processing Record 15 of Set 11 | wanning
# Processing Record 16 of Set 11 | leshukonskoye
# Processing Record 17 of Set 11 | anadyr
# Processing Record 18 of Set 11 | xam nua
# Processing Record 19 of Set 11 | samarai
# Processing Record 20 of Set 11 | xichang
# Processing Record 21 of Set 11 | sorland
# Processing Record 22 of Set 11 | dongying
# Processing Record 23 of Set 11 | abu zabad
# Processing Record 24 of Set 11 | nanakuli
# Processing Record 25 of Set 11 | fort nelson
# Processing Record 26 of Set 11 | kutum
# Processing Record 27 of Set 11 | cururupu
# Processing Record 28 of Set 11 | cheuskiny
# City not found. Skipping
# Processing Record 29 of Set 11 | amudat
# Processing Record 30 of Set 11 | kisangani
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | pindobacu
# Processing Record 33 of Set 11 | kedrovyy
# Processing Record 34 of Set 11 | shu
# Processing Record 35 of Set 11 | riyadh
# Processing Record 36 of Set 11 | turukhansk
# Processing Record 37 of Set 11 | vitim
# Processing Record 38 of Set 11 | samusu
# City not found. Skipping
# Processing Record 39 of Set 11 | babushkin
# Processing Record 40 of Set 11 | kwinana
# Processing Record 41 of Set 11 | umm kaddadah
# Processing Record 42 of Set 11 | saint-michel-des-saints
# Processing Record 43 of Set 11 | nantucket
# Processing Record 44 of Set 11 | zdolbuniv
# Processing Record 45 of Set 11 | charters towers
# Processing Record 46 of Set 11 | guerrero negro
# Processing Record 47 of Set 11 | bantry
# Processing Record 48 of Set 11 | tuy hoa
# Processing Record 49 of Set 11 | sovetskiy
# Processing Record 50 of Set 11 | tumannyy
# City not found. Skipping
# Processing Record 1 of Set 12 | kilindoni
# Processing Record 2 of Set 12 | divnogorsk
# Processing Record 3 of Set 12 | glazov
# Processing Record 4 of Set 12 | sorvag
# City not found. Skipping
# Processing Record 5 of Set 12 | yako
# Processing Record 6 of Set 12 | mancio lima
# Processing Record 7 of Set 12 | bouar
# Processing Record 8 of Set 12 | tevriz
# Processing Record 9 of Set 12 | grafton
# Processing Record 10 of Set 12 | verkhnevilyuysk
# Processing Record 11 of Set 12 | chizhou
# Processing Record 12 of Set 12 | khani
# Processing Record 13 of Set 12 | mount gambier
# Processing Record 14 of Set 12 | ucluelet
# Processing Record 15 of Set 12 | olafsvik
# Processing Record 16 of Set 12 | namtsy
# Processing Record 17 of Set 12 | marang
# Processing Record 18 of Set 12 | kailua
# Processing Record 19 of Set 12 | tambovka
# Processing Record 20 of Set 12 | greensburg
# Processing Record 21 of Set 12 | soure
# Processing Record 22 of Set 12 | evensk
# Processing Record 23 of Set 12 | lugovoy
# Processing Record 24 of Set 12 | bolungarvik
# City not found. Skipping
# Processing Record 25 of Set 12 | guerrero
# Processing Record 26 of Set 12 | mercedes
# Processing Record 27 of Set 12 | caravelas
# Processing Record 28 of Set 12 | kabo
# Processing Record 29 of Set 12 | sakakah
# Processing Record 30 of Set 12 | tunduru
# City not found. Skipping
# Processing Record 31 of Set 12 | ust-kamchatsk
# City not found. Skipping
# Processing Record 32 of Set 12 | andenes
# Processing Record 33 of Set 12 | utiroa
# City not found. Skipping
# Processing Record 34 of Set 12 | sao joao da barra
# Processing Record 35 of Set 12 | camana
# Processing Record 36 of Set 12 | bhum
# Processing Record 37 of Set 12 | pionerskiy
# Processing Record 38 of Set 12 | hamilton
# Processing Record 39 of Set 12 | gorom-gorom
# Processing Record 40 of Set 12 | havoysund
# Processing Record 41 of Set 12 | kyabe
# Processing Record 42 of Set 12 | waipawa
# Processing Record 43 of Set 12 | fethiye
# Processing Record 44 of Set 12 | yei
# Processing Record 45 of Set 12 | tobol
# Processing Record 46 of Set 12 | shasta lake
# Processing Record 47 of Set 12 | caconda
# Processing Record 48 of Set 12 | suleja
# Processing Record 49 of Set 12 | port hedland
# Processing Record 50 of Set 12 | luwuk
# Processing Record 1 of Set 13 | port moresby
# Processing Record 2 of Set 13 | atar
# Processing Record 3 of Set 13 | manacapuru
# Processing Record 4 of Set 13 | kaliua
# Processing Record 5 of Set 13 | tabas
# Processing Record 6 of Set 13 | yeppoon
# Processing Record 7 of Set 13 | dabou
# Processing Record 8 of Set 13 | houma
# Processing Record 9 of Set 13 | ixtapa
# Processing Record 10 of Set 13 | kiama
# Processing Record 11 of Set 13 | kihei
# Processing Record 12 of Set 13 | louisbourg
# City not found. Skipping
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0         Victoria      HK  2022-05-07 17:20:57  22.2855  114.1577     77.38
# 1        Hithadhoo      MV  2022-05-07 17:22:11  -0.6000   73.0833     84.42
# 2  Arraial Do Cabo      BR  2022-05-07 17:19:14 -22.9661  -42.0278     78.66
# 3            Pisco      PE  2022-05-07 17:22:12 -13.7000  -76.2167     70.02
# 4         San Luis      AR  2022-05-07 17:22:12 -33.2950  -66.3356     76.51
# 5     San Patricio      US  2022-05-07 17:22:13  28.0170  -97.5169     91.08
# 6      Port Alfred      ZA  2022-05-07 17:22:13 -33.5906   26.8910     64.18
# 7         Thompson      CA  2022-05-07 17:22:14  55.7435  -97.8558     60.96
# 8     Polunochnoye      RU  2022-05-07 17:22:15  60.8697   60.4153     40.48
# 9      Saint-Louis      SN  2022-05-07 17:22:15  16.3333  -15.0000    107.24
#
#    Humidity  Cloudiness  Wind Speed
# 0        80         100        3.00
# 1        76          72       14.56
# 2        65          40       14.97
# 3        78          25       12.66
# 4        26           1       17.22
# 5        42           6       11.34
# 6        87          88        3.00
# 7        63          20       10.36
# 8        91          95        4.85
# 9         8           3       12.64

# %%
# Create the output file (CSV).

output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.

import time

# Get today's date in seconds.

today = time.time()

today
# Out:
# 1651944449.789789

# %%
# Import time module

import time

# Build the scatter plot for latitude vs. max temperature.

plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))

plt.ylabel("Max Temperature (F)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig1.png")

# Show plot.

plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.

plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))

plt.ylabel("Humidity (%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig1.png")

# Show plot.

plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.

plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))

plt.ylabel("Cloudiness (%)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig3.png")

# Show plot.

plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.

plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.

plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))

plt.ylabel("Wind Speed (mph)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure.

plt.savefig("weather_data/Fig4.png")

# Show plot.

plt.show()
